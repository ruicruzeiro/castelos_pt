# %% [markdown]
# PORTUGUESE ISLANDS - Rui Cruzeiro, December 2022

# %% [markdown]
# The list of Portuguese islands was extracted from a text file built with the information from this website: https://web.archive.org/web/20140424121050/http://cq0odx.clanteam.com/P.I.P%20Ref.htm

# %% [markdown]
# In order to show them on a map, we need their geographical coordinates. The list has 200 islands, so the quickest way to get all coordinates is through requests to the Google Maps Platform API. It won't be able to get all of them, so there will be a few islands that need their coordinates to be inputted manually.

# %% [markdown]
# The following packages were used:

# %%
import re
import requests
import time                   # To sleep between each API request
from api_key import api_key   # I used my private API key

# %% [markdown]
# The island names were used to create a dictionary to store island information.

# %%
# Get info from file
island_dict = {}
file = open('islands.txt','r')
islands = file.readlines()

for island in islands:
    
    # Get name
    name = re.split('\t', island)[1]
    
    # Remove whitespace
    name = name.rstrip()
    
    # Remove double spaces
    name = name.replace('  ', ' ')

    # Capitalize correctly
    name = name.title()
    name = name.replace(' De ', ' de ')
    name = name.replace(' Da ', ' da ')
    name = name.replace(' Do ', ' do ')
    name = name.replace(' Das ', ' das ')
    name = name.replace(' Dos ', ' dos ')
    
    # Store in dictionary
    island_dict[name] = {'coordinates': 'INPUT MANUALLY'}

# %% [markdown]
# The island names were also used to build the URL to use in the request to the API.

# %%
count_all = 0
count_missing = 0

for island, info in island_dict.items():
    
    count_all += 1
    
    # GET request
    island_url = '+'.join(list(island.split())) + '+portugal'
    url = 'https://maps.googleapis.com/maps/api/geocode/json?address=' + island_url + ',+CA&key=' + api_key
    response = requests.get(url).json()
    
    # Store latitude and longitude from response json into island dictionary    
    if response['results'] != []:
        lat = response['results'][0]['geometry']['location']['lat']
        lon = response['results'][0]['geometry']['location']['lng']
        info['coordinates'] = [lat, lon]
        print(str(count_all) + ' - coordinates added: ' + island)
    else:
        print(str(count_all) + ' - coordinates missing: ' + island)
        count_missing += 1
    
    # Keeping the API happy
    time.sleep(1)

print('')
print('***DONE***')
print('Coordinates added:', count_all - count_missing)
print('Coordinates missing:', count_missing)
print('Total islands: ', count_all)
# Out:
# 1 - coordinates added: Ilha da Ínsua
# 2 - coordinates added: Ilhéu da Ínsua Velha
# 3 - coordinates added: Ilha dos Amores (Rio Minho)
# 4 - coordinates added: Ilha da Boega (Rio Minho)
# 5 - coordinates missing: Ilhéu Marreco
# 6 - coordinates added: Ilhéu Monte Farinha
# 7 - coordinates added: Ilha da Testada (Ria de Aveiro)
# 8 - coordinates added: Ilha dos Ovos
# 9 - coordinates added: Ilha da Gaga (Ria de Aveiro)
# 10 - coordinates added: Ilha da Gaivota
# 11 - coordinates added: Ilha da Pedra
# 12 - coordinates added: Ilha do Parrachil (Ria de Aveiro)
# 13 - coordinates added: Ilha da Mó do Meio (Ria de Aveiro)
# 14 - coordinates added: Ilha de Samos
# 15 - coordinates added: Ilha do Poço
# 16 - coordinates missing: Ilha da Tranqueira
# 17 - coordinates added: Ilha do Amoroso (Ria de Aveiro)
# 18 - coordinates added: Ilha da Murraceira (Rio Mondego - Fig. da Foz)
# 19 - coordinates missing: Ilha da Turbina
# 20 - coordinates added: Ilha do Gramatal (Ria de Aveiro)
# 21 - coordinates added: Ilha da Marinha Nova
# 22 - coordinates missing: Ilha de Matadouce
# 23 - coordinates added: Ilha da Idanha
# 24 - coordinates added: Ilha A Nova
# 25 - coordinates missing: Ilha dos Tres Postes
# 26 - coordinates added: Ilha do Marechal
# 27 - coordinates added: Ilha Carmona
# 28 - coordinates added: Ilha da Estrada
# 29 - coordinates added: Ilha da Berlenga Grande
# 30 - coordinates added: Ilha do Baleal
# 31 - coordinates added: Areal do Bugio (Barra do Tejo)
# 32 - coordinates added: Ilha do Bugio / Farol (Barra do Tejo)
# 33 - coordinates added: Ilhéus das Estelas
# 34 - coordinates added: Ilhéus dos Farilhões
# 35 - coordinates added: Ilhéu de Fora (Berlenga)
# 36 - coordinates added: Ilha do Rato
# 37 - coordinates missing: Ilha do Cambalhão
# 38 - coordinates added: Mouchão das Corças
# 39 - coordinates added: Mouchão do Bolinhas
# 40 - coordinates added: Ilhéu da Vélha (Berlenga)
# 41 - coordinates added: Ilhéu da Dª Inês (Berlenga)
# 42 - coordinates added: Ilhéu Maldito (Berlenga)
# 43 - coordinates added: Ilhéu da Quebrada (Berlenga)
# 44 - coordinates added: Ilhéu dos Soldados (Berlenga)
# 45 - coordinates added: Ilhéu da Lingua (Berlenga)
# 46 - coordinates added: Ilhéu Cuiaba Ou Ponta (Berlenga)
# 47 - coordinates added: Ilhéu do Meio (Berlenga)
# 48 - coordinates added: Ilhéu das Pombas (Baleal)
# 49 - coordinates added: Ilhéu Terra (Baleal)
# 50 - coordinates added: Ilhéu de Fora (Baleal)
# 51 - coordinates added: Ilhéu da Papôa (Peniche)
# 52 - coordinates added: Ilha dos Canivetes/Ponta do Arinho (Foz do Arelho)
# 53 - coordinates added: Pedra do Pata (Peniche)
# 54 - coordinates added: Ilha da Moacha Norte (Ria de Aveiro)
# 55 - coordinates added: Ilha do Parque (Caldas da Rainha)
# 56 - coordinates added: Ilha do Rebocho (Ria de Aveiro)
# 57 - coordinates added: Ilha do Ermal (Vieira do Minho)
# 58 - coordinates added: Ilha da Morraceira (Lanhelas, Rio Minho)
# 59 - coordinates added: Ilhéu do Forte S. João Batista (Berlenga)
# 60 - coordinates added: Ilha de Almourol (Castelo)
# 61 - coordinates added: Ilha do Lombo
# 62 - coordinates added: Ilha da Agolada
# 63 - coordinates added: Ilha Verde
# 64 - coordinates added: Mouchão de Alhandra
# 65 - coordinates added: Mouchão das Carças
# 66 - coordinates added: Mouchão Lombo do Tejo
# 67 - coordinates added: Mouchão da Povoa
# 68 - coordinates added: Mouchão da Ponte (Casal Fidalgo)
# 69 - coordinates added: Mouchão da Valada (Valada)
# 70 - coordinates added: Mouchão do Martelo (Valada)
# 71 - coordinates added: Mouchão da Cheia (Valada)
# 72 - coordinates added: Mouchão da Lebre (Valada)
# 73 - coordinates added: Mouchão dos Caracóis (Valada)
# 74 - coordinates added: Mouchão do Crescido Ou Choupos (Valada)
# 75 - coordinates added: Mouchão da Casa Branca
# 76 - coordinates added: Mouchão do Malagueiro
# 77 - coordinates added: Mouchão Obras Grande
# 78 - coordinates added: Mouchão Obras Pequeno
# 79 - coordinates added: Ilha Escaroupim (Escaroupim)
# 80 - coordinates added: Ilha do Pessegueiro
# 81 - coordinates added: Ilhéu Norte Pessegueiro
# 82 - coordinates added: Ilhéu Oeste Pessegueiro
# 83 - coordinates added: Ilha da Perceveira
# 84 - coordinates added: Pedra da Foz
# 85 - coordinates added: Pedra da Atalaia
# 86 - coordinates added: Pedra dos Corvos
# 87 - coordinates added: Ilha Ariana
# 88 - coordinates missing: Ilha do Moinho
# 89 - coordinates added: Ilha Monte Branco
# 90 - coordinates added: Ilha Juromenha
# 91 - coordinates added: Ilha de Bacelos
# 92 - coordinates added: Ilha de Bacelos Pequena
# 93 - coordinates added: Ilha da Palmeira
# 94 - coordinates added: Ilha da Palmeira Pequena
# 95 - coordinates added: Ilha Azenha Brava
# 96 - coordinates added: Ilha Leziria Internacional
# 97 - coordinates added: Ilha do São Bras
# 98 - coordinates added: Ilha da Culatra (Faro)
# 99 - coordinates added: Ilha de Tavira (Tavira)
# 100 - coordinates added: Ilha da Da Barreta (Faro)
# 101 - coordinates added: Ilha da Armona (Olhão)
# 102 - coordinates added: Ilha do Martinhal (Vila do Bispo)
# 103 - coordinates added: Ilha de Faro (Not Island Anymore)
# 104 - coordinates added: Ilha das Cabanas (Tavira)
# 105 - coordinates added: Ilha do Côco (Olhão)
# 106 - coordinates added: Ilha da Cobra (Faro)
# 107 - coordinates added: Ilha das Alturas (Olhão)
# 108 - coordinates added: Ilhéu dos Gemidos (Faro)
# 109 - coordinates added: Ilhote do Pego (Faro)
# 110 - coordinates added: Ilhote das Ratas (Faro)
# 111 - coordinates added: Ilhote do Cabo (Faro)
# 112 - coordinates missing: Ilhote das Trombolas
# 113 - coordinates added: Ilhote da Margalha (Faro)
# 114 - coordinates added: Pedra das Gaivotas (Vila do Bispo)
# 115 - coordinates added: Pedra do Cachado (Vila do Bispo)
# 116 - coordinates missing: Ilha da Safra
# 117 - coordinates added: Ilha do Freixial
# 118 - coordinates missing: Ilha da Lebre
# 119 - coordinates missing: Ilha da Cascalheira
# 120 - coordinates added: Ilhéu Nossa Srª do Rosário (Portimão)
# 121 - coordinates added: Ilha do Barro (Faro)
# 122 - coordinates added: Ilha da Geada (Faro)
# 123 - coordinates added: Ilha da Cruz (Olhão)
# 124 - coordinates added: Ilha da Praia dos Tesos (Faro)
# 125 - coordinates added: Ilha das Ratas S. Lourenço (Olhão)
# 126 - coordinates added: Pedra da Anicha (Portinho da Arrábida)
# 127 - coordinates added: Pedra do Leão (Sesimbra)
# 128 - coordinates added: Pedra do Temporal (Praia Temporal, Sesimbra)
# 129 - coordinates added: Pedra da Agulha (Arrifana, Aljezur)
# 130 - coordinates missing: Barragem da Bravura #1
# 131 - coordinates missing: Barragem da Bravura #2
# 132 - coordinates missing: Barragem da Bravura #3
# 133 - coordinates missing: Barragem do Arade #1
# 134 - coordinates missing: Barragem de Odeleite #1
# 135 - coordinates missing: Barragem de Odeleite #2
# 136 - coordinates missing: Barragem de Odeleite #3
# 137 - coordinates missing: Barragem de Odeleite #4
# 138 - coordinates missing: Barragem de Odeleite #5
# 139 - coordinates missing: Barragem de Odeleite #6
# 140 - coordinates missing: Barragem de Odeleite #7
# 141 - coordinates missing: Barragem do Beliche #1
# 142 - coordinates added: Ilha de Santa Maria (Cu1)
# 143 - coordinates added: Ilha de São Miguel (Cu2)
# 144 - coordinates added: Ilha Terceira (Cu3)
# 145 - coordinates added: Ilha da Graciosa (Cu4)
# 146 - coordinates added: Ilha de São Jorge (Cu5)
# 147 - coordinates added: Ilha do Pico (Cu6)
# 148 - coordinates added: Ilha do Faial (Cu7)
# 149 - coordinates added: Ilha das Flores Cu8)
# 150 - coordinates added: Ilha do Corvo (Cu9)
# 151 - coordinates added: Ilhéu das Cabras Grande (Cu3)
# 152 - coordinates added: Ilhéu das Cabras Pequeno (Cu3)
# 153 - coordinates added: Ilhéu da Vila (Cu1)
# 154 - coordinates added: Ilhéus das Formigas (Cu1)
# 155 - coordinates added: Ilhéu dos Mosteiros (Cu2)
# 156 - coordinates added: Ilhéu do Norte (Cu3)
# 157 - coordinates added: Ilhéu dos Fradinhos (Cu3)
# 158 - coordinates added: Ilhéu da Praia (Cu4)
# 159 - coordinates added: Ilhéu de Baixo  (Cu4)
# 160 - coordinates added: Ilhéu do Topo (Cu5)
# 161 - coordinates added: Ilhéu Deitado (Cu6)
# 162 - coordinates added: Ilhéu da Gadelha (Cu8)
# 163 - coordinates added: Ilhéu de Monchique (Cu8)
# 164 - coordinates added: Ilhéu de Álvaro Rodrigues (Cu8)
# 165 - coordinates added: Ilhéu da Feteira (Cu3)
# 166 - coordinates added: Ilhéu das Lagoinhas (Cu1)
# 167 - coordinates added: Ilhéu de Vila Franca do Campo (Cu2)
# 168 - coordinates added: Ilhéu Se São Lourenço (Cu1)
# 169 - coordinates added: Ilha da Madeira
# 170 - coordinates added: Ilha Porto Santo
# 171 - coordinates added: Ilhéu do Chão (Desertas)
# 172 - coordinates added: Ilha Selvagem Grande
# 173 - coordinates added: Ilha Deserta Grande
# 174 - coordinates added: Ilhéu Mole (Madeira)
# 175 - coordinates added: Ilhéu de Fora (Madeira)
# 176 - coordinates missing: Ilhéu de Agostinho
# 177 - coordinates added: Ilhéu das Cenouras (Porto Santo)
# 178 - coordinates added: Ilhéu de Cima (Porto Santo)
# 179 - coordinates added: Ilhéu de Fora (Porto Santo)
# 180 - coordinates added: Ilhéu de Ferro (Porto Santo)
# 181 - coordinates added: Ilhéu Fonte da Areia
# 182 - coordinates added: Ilhéu de Baixo Ou Cal (Porto Santo)
# 183 - coordinates added: Ilhéu do Bugio (Desertas)
# 184 - coordinates missing: Ilhéu Farilhão
# 185 - coordinates added: Ilha Selvagem Pequena
# 186 - coordinates added: Ilhéu Comprido (Selvagens)
# 187 - coordinates added: Ilhéu de Fora (Selvagens)
# 188 - coordinates added: Ilhéu do Norte (Selvagens)
# 189 - coordinates added: Ilhéu Redondo (Selvagens)
# 190 - coordinates added: Ilhéu da Terra (Selvagens)
# 191 - coordinates added: Ilhéu do Mar (Selvagens)
# 192 - coordinates added: Ilhéu da Viúva Ou Rocha do Navio (Madeira)
# 193 - coordinates added: Ilhéu Vermelho (Madeira)
# 194 - coordinates added: Ilhéu Preto (Madeira)
# 195 - coordinates added: Ilhéu da Forja (Madeira)
# 196 - coordinates added: Ilhéu do Gorgulho (Madeira)
# 197 - coordinates added: Ilhéus da Janela (Madeira)
# 198 - coordinates added: Ilhéus da Rib (Madeira)
# 199 - coordinates added: Ilhéu da Rocha das Vinhas (Madeira)
# 200 - coordinates added: Ilhéu do Farol (Farol S. Lourenço)
#
# ***DONE***
# Coordinates added: 175
# Coordinates missing: 25
# Total islands:  200

# %%
with open("island_dict.txt", 'w') as file: 
    for key, value in island_dict.items(): 
        file.write('%s:%s\n' % (key, value))
