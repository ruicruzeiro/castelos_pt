# %% [markdown]
# PORTUGUESE CASTLES

# %% [markdown]
# February 2023 - Rui Cruzeiro
#
# This notebook creates a dictionary with the names of Portuguese castles, as well as some information about each of them. It was created as a part of my personal portfolio.

# %%
import requests
import folium as fl
from bs4 import BeautifulSoup
import time
import random

# %% [markdown]
# The information about the castles was retrieved from the castelosdeportugal.pt website through web scraping. Since we get a `403 - Forbidden` while using BeautifulSoup, I needed to use the ScrapeOps API (scrapeops.io) to be able to extract the information from the website.

# %%
API_KEY = '63716ad6-e533-46c1-8f2e-db3895ad9685'

response = requests.get(
  url='https://proxy.scrapeops.io/v1/',
  params={
      'api_key': API_KEY,
      'url': 'https://www.castelosdeportugal.pt/castelos/SiteMap.html', 
  },
)

soup = BeautifulSoup(response.content, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="width=device-width" name="viewport"/>
# <title>Índice</title>
# <style>
# 			body{
# 			background-color:#373e48;
# 			font-family:"Times New Roman", Times, serif;
# 			}
# 			.center{
# 			text-align:center;
# 			}
# 			h1{
# 			text-align:center;
# 			margin:0;
# 			color:#ffff;
# 			}
# 			h4{
# 			Color:#ffff;
# 			margin-bottom:0px;
# 			margin-top:.5rem;
# 			}
# 			h3 {
# 			font-size:2em;
# 			text-align:center;
# 			}
# 			a {
# 			padding-left:10px;
# 			padding-right:10px;
# 			}
# 			a:link {
# 			color:#ffe30a;
# 			font-style:italic;
# 			}
# 			a:visited {
# 			color:#ffe30a;
# 			}
# 			.floatLeft {
# 			float:left;
# 			}
# 			h3 a{
# 			color:#000000;
# 			}
# 			#indice{
# 			font-size:1.2em;
# 			background-color:#373e48;
# 			}
# 		</style>
# </head>
# <body>
# <div id="indice">
# <h1>Castelos de Portugal</h1>
# <div class="row">
# <h4>A</h4>
# <a href="CastelosSECXII/abrantes.html" rel="nofollow">Abrantes</a>
# <a href="Castelos(pre)SECXII/aguiarSousa.html" rel="nofollow">Aguiar Sousa</a>
# <a href="CastelosSECXII/alcacerSal.html" rel="nofollow">Alcácer do Sal</a>
# <a href="Castelos(pre)SECXII/alcanede.html" rel="nofollow">Alcanede</a>
# <a href="Castelos(pre)SECXII/alcobaca.html" rel="nofollow">Alcobaça</a>
# <a href="CastelosSECXII/alcantarilha.html" rel="nofollow">Alcantarilha</a>
# <a href="CastelosSECXII/alfaiates.html" rel="nofollow">Alfaiates</a>
# <a href="CastelosSECXII/alfeizerao.html" rel="nofollow">Alfeizerão</a>
# <a href="Castelos(pre)SECXII/aljezur.html" rel="nofollow">Aljezur</a>
# <a href="CastelosSECXII/aljustrel.html" rel="nofollow">Aljustrel</a>
# <a href="CastelosSECXII/alenquer.html" rel="nofollow">Alenquer</a>
# <a href="CastelosSECXII/almada.html" rel="nofollow">Almada</a>
# <a href="CastelosSECXII/almourol.html" rel="nofollow">Almourol</a>
# <a href="Castelos(pos)SECXIII/alterChao.html" rel="nofollow">Alter do Chão</a>
# <a href="Castelos(pre)SECXII/alva.html" rel="nofollow">Alva</a>
# <a href="Castelos(pos)SECXIII/alvito.html" rel="nofollow">Alvito</a>
# <a href="Castelos(pre)SECXII/alvor.html" rel="nofollow">Alvor</a>
# <a href="Castelos(pos)SECXIII/amieira.html" rel="nofollow">Amieira</a>
# <a href="CastelosSECXII/alpalhao.html" rel="nofollow">Alpalhão</a>
# <a href="Castelos(pos)SECXIII/arraiolos.html" rel="nofollow">Arraiolos</a>
# <a href="Castelos(pre)SECXII/ansiaes.html" rel="nofollow">Ansiães</a>
# <a href="Castelos(pre)SECXII/atouguiaBaleia.html" rel="nofollow">Atouguia da Baleia</a>
# <a href="CastelosSECXII/avo.html" rel="nofollow">Avô</a>
# </div>
# <div class="row">
# <h4>B</h4>
# <a href="Castelos(pre)SECXII/barcelos.html" rel="nofollow">Barcelos</a>
# <a href="CastelosSECXIII/braga.html" rel="nofollow">Braga</a>
# <a href="CastelosSECXIII/braganca.html" rel="nofollow">Bragança</a>
# </div>
# <div class="row">
# <h4>C</h4>
# <a href="CastelosSECXII/cabecoVide.html" rel="nofollow">Cabeço de Vide</a>
# <a href="Castelos(pre)SECXII/cacela.html" rel="nofollow">Cacela</a>
# <a href="Castelos(pre)SECXII/caminha.html" rel="nofollow">Caminha</a>
# <a href="Castelos(pre)SECXII/carrapatoso.html" rel="nofollow">Carrapatoso</a>
# <a href="CastelosSECXIII/casteloBom.html" rel="nofollow">Castelo Bom</a>
# <a href="Castelos(pre)SECXII/casteloMelhor.html" rel="nofollow">Castelo Melhor</a>
# <a href="CastelosSECXIII/casteloMendo.html" rel="nofollow">Castelo Mendo</a>
# <a href="CastelosSECXII/casteloNovo.html" rel="nofollow">Castelo Novo</a>
# <a href="CastelosSECXII/casteloRodrigo.html" rel="nofollow">Castelo Rodrigo</a>
# <a href="Castelos(pre)SECXII/castroMarim.html" rel="nofollow">Castro Marim</a>
# <a href="Castelos(pre)SECXII/castroLaboreiro.html" rel="nofollow">Castro Laboreiro</a>
# <a href="CastelosSECXII/celoricoBeira.html" rel="nofollow">Celorico da Beira</a>
# <a href="Castelos(pre)SECXII/ceras.html" rel="nofollow">Ceras</a>
# <a href="Castelos(pre)SECXII/chaves.html" rel="nofollow">Chaves</a>
# <a href="CastelosSECXII/coimbra.html" rel="nofollow">Coimbra</a>
# <a href="Castelos(pre)SECXII/cola.html" rel="nofollow">Cola</a>
# <a href="CastelosSECXII/covilha.html" rel="nofollow">Covilhã</a>
# </div>
# <div class="row">
# <h4>E</h4>
# <a href="CastelosSECXII/estremoz.html" rel="nofollow">Estremoz</a>
# <a href="Castelos(pos)SECXIII/evora.html" rel="nofollow">Évora</a>
# <a href="CastelosSECXII/evoraMonte.html" rel="nofollow">Évora Monte</a>
# </div>
# <div class="row">
# <h4>F</h4>
# <a href="Castelos(pre)SECXII/faria.html" rel="nofollow">Faria</a>
# <a href="Castelos(pre)SECXII/faro.html" rel="nofollow">Faro</a>
# <a href="CastelosSECXII/ferreiraAves.html" rel="nofollow">Ferreira de Aves</a>
# <a href="Castelos(pre)SECXII/folgosinho.html" rel="nofollow">Folgosinho</a>
# <a href="CastelosSECXII/freixoEspada.html" rel="nofollow">Freixo de Espada à Cinta</a>
# </div>
# <div class="row">
# <h4>G</h4>
# <a href="Castelos(pre)SECXII/gaia.html" rel="nofollow">Gaia</a>
# <a href="CastelosSECXII/germanelo.html" rel="nofollow">Germanelo</a>
# <a href="Castelos(pre)SECXII/giraldo.html" rel="nofollow">Giraldo</a>
# <a href="Castelos(pre)SECXII/gouveia.html" rel="nofollow">Gouveia</a>
# <a href="CastelosSECXII/guarda.html" rel="nofollow">Guarda</a>
# <a href="Castelos(pre)SECXII/guimaraes.html" rel="nofollow">Guimarães</a>
# </div>
# <div class="row">
# <h4>I</h4>
# <a href="CastelosSECXII/idanhaNova.html" rel="nofollow">Idanha-a-Nova</a>
# <a href="CastelosSECXII/idanhaVelha.html" rel="nofollow">Idanha-a-Velha</a>
# </div>
# <div class="row">
# <h4>L</h4>
# <a href="Castelos(pre)SECXII/lagos.html" rel="nofollow">Lagos</a>
# <a href="Castelos(pre)SECXII/lamego.html" rel="nofollow">Lamego</a>
# <a href="Castelos(pre)SECXII/lanhoso.html" rel="nofollow">Lanhoso</a>
# <a href="CastelosSECXII/leiria.html" rel="nofollow">Leiria</a>
# <a href="CastelosSECXIII/lindoso.html" rel="nofollow">Lindoso</a>
# <a href="CastelosSECXII/linharesBeira.html" rel="nofollow">Linhares da Beira</a>
# <a href="Castelos(pre)SECXII/longroiva.html" rel="nofollow">Longroiva</a>
# <a href="Castelos(pre)SECXII/loule.html" rel="nofollow">Loulé</a>
# <a href="CastelosSECXII/lourinha.html" rel="nofollow">Lourinhã</a>
# <a href="Castelos(pre)SECXII/lousa.html" rel="nofollow">Lousã</a>
# </div>
# <div class="row">
# <h4>M</h4>
# <a href="CastelosSECXII/marialva.html" rel="nofollow">Marialva</a>
# <a href="Castelos(pre)SECXII/mauVizinho.html" rel="nofollow">Mau Vizinho</a>
# <a href="Castelos(pre)SECXII/mauVizinhoEvora.html" rel="nofollow">Mau Vizinho(Évora)</a>
# <a href="CastelosSECXII/melgaco.html" rel="nofollow">Melgaço</a>
# <a href="Castelos(pre)SECXII/mertola.html" rel="nofollow">Mértola</a>
# <a href="Castelos(pre)SECXII/messejana.html" rel="nofollow">Messejana</a>
# <a href="Castelos(pre)SECXII/mirandaDouro.html" rel="nofollow">Miranda do Douro</a>
# <a href="CastelosSECXII/mogadouro.html" rel="nofollow">Mogadouro</a>
# <a href="CastelosSECXII/monforte.html" rel="nofollow">Monforte</a>
# <a href="CastelosSECXII/monforteFigRodrigo.html" rel="nofollow">Monforte (Fig.C.Rodrigo)</a>
# <a href="CastelosSECXII/monsanto.html" rel="nofollow">Monsanto</a>
# <a href="CastelosSECXII/monsaraz.html" rel="nofollow">Monsaraz</a>
# <a href="Castelos(pre)SECXII/montel.html" rel="nofollow">Montel</a>
# <a href="Castelos(pre)SECXII/montemorVelho.html" rel="nofollow">Montemor-o-Velho</a>
# <a href="CastelosSECXII/moreiraRei.html" rel="nofollow">Moreira de Rei</a>
# </div>
# <div class="row">
# <h4>N</h4>
# <a href="Castelos(pre)SECXII/neiva.html" rel="nofollow">Neiva</a>
# <a href="CastelosSECXII/numao.html" rel="nofollow">Numão</a>
# </div>
# <div class="row">
# <h4>O</h4>
# <a href="CastelosSECXII/obidos.html" rel="nofollow">Óbidos</a>
# <a href="Castelos(pre)SECXII/oleiros.html" rel="nofollow">Oleiros</a>
# <a href="CastelosSECXII/ourem.html" rel="nofollow">Ourém</a>
# </div>
# <div class="row">
# <h4>P</h4>
# <a href="Castelos(pre)SECXII/paderne.html" rel="nofollow">Paderne</a>
# <a href="CastelosSECXII/palmela.html" rel="nofollow">Palmela</a>
# <a href="Castelos(pre)SECXII/penaAguiar.html" rel="nofollow">Pena de Aguiar</a>
# <a href="Castelos(pre)SECXII/penacova.html" rel="nofollow">Penacova</a>
# <a href="CastelosSECXII/penamacor.html" rel="nofollow">Penamacor</a>
# <a href="CastelosSECXII/penasRoias.html" rel="nofollow">Penas Róias</a>
# <a href="Castelos(pre)SECXII/penedono.html" rel="nofollow">Penedono</a>
# <a href="CastelosSECXII/penela.html" rel="nofollow">Penela</a>
# <a href="Castelos(pre)SECXII/piconha.html" rel="nofollow">Piconha</a>
# <a href="CastelosSECXIII/pinhel.html" rel="nofollow">Pinhel</a>
# <a href="CastelosSECXII/pombal.html" rel="nofollow">Pombal</a>
# <a href="Castelos(pre)SECXII/portelo.html" rel="nofollow">Portelo</a>
# <a href="Castelos(pre)SECXII/portoMos.html" rel="nofollow">Porto de Mós</a>
# <a href="Castelos(pre)SECXII/proencaVelha.html" rel="nofollow">Proença-a-Velha</a>
# </div>
# <div class="row">
# <h4>R</h4>
# <a href="CastelosSECXII/rodao.html" rel="nofollow">Rodão</a>
# <a href="Castelos(pre)SECXII/reliquias.html" rel="nofollow">Relíquias</a>
# <a href="Castelos(pre)SECXII/romanoLousa.html" rel="nofollow">Romano da Lousa</a>
# <a href="Castelos(pre)SECXII/roqueiroCoruto.html" rel="nofollow">Roqueiro de Coruto</a>
# </div>
# <div class="row">
# <h4>S</h4>
# <a href="CastelosSECXII/sabugal.html" rel="nofollow">Sabugal</a>
# <a href="Castelos(pre)SECXII/martinhoMouros.html" rel="nofollow">São Martinho de Mouros </a>
# <a href="Castelos(pre)SECXII/sJorge.html" rel="nofollow">São Jorge</a>
# <a href="Castelos(pre)SECXII/salir.html" rel="nofollow">Salir</a>
# <a href="CastelosSECXII/salvaterraExtremo.html" rel="nofollow">Salvaterra do Extremo</a>
# <a href="Castelos(pre)SECXII/santaMaria.html" rel="nofollow">Santa Maria da Feira</a>
# <a href="Castelos(pre)SECXII/santarem.html" rel="nofollow">Santarém</a>
# <a href="Castelos(pre)SECXII/santiagoCacem.html" rel="nofollow">Santiago do Cacém</a>
# <a href="CastelosSECXII/santoEstevao.html" rel="nofollow">Santo Estêvão</a>
# <a href="Castelos(pre)SECXII/seia.html" rel="nofollow">Seia</a>
# <a href="Castelos(pre)SECXII/sernancelhe.html" rel="nofollow">Sernancelhe</a>
# <a href="CastelosSECXII/serta.html" rel="nofollow">Sertã</a>
# <a href="Castelos(pre)SECXII/silves.html" rel="nofollow">Silves</a>
# <a href="Castelos(pos)SECXIII/sines.html" rel="nofollow">Sines</a>
# <a href="Castelos(pre)SECXII/sintra.html" rel="nofollow">Sintra</a>
# <a href="Castelos(pre)SECXII/soure.html" rel="nofollow">Soure</a>
# <a href="CastelosSECXIII/sortelha.html" rel="nofollow">Sortelha</a>
# </div>
# <div class="row">
# <h4>T</h4>
# <a href="Castelos(pre)SECXII/tarouca.html" rel="nofollow">Tarouca</a>
# <a href="Castelos(pre)SECXII/tavira.html" rel="nofollow">Tavira</a>
# <a href="CastelosSECXII/tomar.html" rel="nofollow">Tomar</a>
# <a href="Castelos(pre)SECXII/torresNovas.html" rel="nofollow">Torres Novas</a>
# <a href="Castelos(pre)SECXII/torresVedras.html" rel="nofollow">Torres Vedras</a>
# <a href="Castelos(pre)SECXII/trancoso.html" rel="nofollow">Trancoso</a>
# </div>
# <div class="row">
# <h4>V</h4>
# <a href="CastelosSECXIII/veiros.html" rel="nofollow">Veiros</a>
# <a href="Castelos(pre)SECXII/velhoAlcoutim.html" rel="nofollow">Velho de Alcoutim</a>
# <a href="Castelos(pre)SECXII/velhoDegebe.html" rel="nofollow">Velho do Degebe</a>
# <a href="Castelos(pre)SECXII/vermoim.html" rel="nofollow">Vermoim</a>
# <a href="Castelos(pos)SECXIII/vianaAlentejo.html" rel="nofollow">Viana do Alentejo</a>
# <a href="CastelosSECXII/vidigueira.html" rel="nofollow">Vidigueira</a>
# <a href="Castelos(pre)SECXII/verdeFrancos.html" rel="nofollow">Vila Verde dos Francos</a>
# <a href="Castelos(pos)SECXIII/vilaVicosa.html" rel="nofollow">Vila Viçosa</a>
# <a href="Castelos(pre)SECXII/vilarMaior.html" rel="nofollow">Vilar Maior</a>
# <a href="Castelos(pre)SECXII/vinhais.html" rel="nofollow">Vinhais</a>
# <a href="Castelos(pre)SECXII/viseu.html" rel="nofollow">Viseu</a>
# </div>
# </div>
# <div>
# <h3><a href="https://pt.wikipedia.org/wiki/Cronologia_da_hist%C3%B3ria_de_Portugal" rel="noopener noreferrer" target="_blank">Cronologia da história de Portugal</a></h3>
# <h3><a href="https://pt.wikipedia.org/wiki/Lista_de_monarcas_de_Portugal" rel="noopener noreferrer" target="_blank">Lista de monarcas de Portugal</a></h3>
# </div>
# <div class="center" id="div-foot">
# <a href="https://www.castelosdeportugal.pt/index.html">Home</a>
# <a href="Politica_de_privacidade.html">Política de privacidade</a>
# <a href="Termos_e_Condicoes.html">Termos e Condições</a>
# <a href="Contatos.html">Contatos</a>
# </div>
# </body>
# </html>

# %% [markdown]
# In the castelosdeportugal.pt website, the castle information is shown on individual html pages. Let's first store the URL of each page to be able to parse them one by one later.

# %%
castles_html_dict = {}

for letter in soup.find_all('div', class_='row'):
    for castle_entry in letter.find_all('a'):
        castles_html_dict[castle_entry.string] = castle_entry.get('href')
        
castles_html_dict
# Out:
# {'Abrantes': 'CastelosSECXII/abrantes.html',
#  'Aguiar Sousa': 'Castelos(pre)SECXII/aguiarSousa.html',
#  'Alcácer do Sal': 'CastelosSECXII/alcacerSal.html',
#  'Alcanede': 'Castelos(pre)SECXII/alcanede.html',
#  'Alcobaça': 'Castelos(pre)SECXII/alcobaca.html',
#  'Alcantarilha': 'CastelosSECXII/alcantarilha.html',
#  'Alfaiates': 'CastelosSECXII/alfaiates.html',
#  'Alfeizerão': 'CastelosSECXII/alfeizerao.html',
#  'Aljezur': 'Castelos(pre)SECXII/aljezur.html',
#  'Aljustrel': 'CastelosSECXII/aljustrel.html',
#  'Alenquer': 'CastelosSECXII/alenquer.html',
#  'Almada': 'CastelosSECXII/almada.html',
#  'Almourol': 'CastelosSECXII/almourol.html',
#  'Alter do Chão': 'Castelos(pos)SECXIII/alterChao.html',
#  'Alva': 'Castelos(pre)SECXII/alva.html',
#  'Alvito': 'Castelos(pos)SECXIII/alvito.html',
#  'Alvor': 'Castelos(pre)SECXII/alvor.html',
#  'Amieira': 'Castelos(pos)SECXIII/amieira.html',
#  'Alpalhão': 'CastelosSECXII/alpalhao.html',
#  'Arraiolos': 'Castelos(pos)SECXIII/arraiolos.html',
#  'Ansiães': 'Castelos(pre)SECXII/ansiaes.html',
#  'Atouguia da Baleia': 'Castelos(pre)SECXII/atouguiaBaleia.html',
#  'Avô': 'CastelosSECXII/avo.html',
#  'Barcelos': 'Castelos(pre)SECXII/barcelos.html',
#  'Braga': 'CastelosSECXIII/braga.html',
#  'Bragança': 'CastelosSECXIII/braganca.html',
#  'Cabeço de Vide': 'CastelosSECXII/cabecoVide.html',
#  'Cacela': 'Castelos(pre)SECXII/cacela.html',
#  'Caminha': 'Castelos(pre)SECXII/caminha.html',
#  'Carrapatoso': 'Castelos(pre)SECXII/carrapatoso.html',
#  'Castelo Bom': 'CastelosSECXIII/casteloBom.html',
#  'Castelo Melhor': 'Castelos(pre)SECXII/casteloMelhor.html',
#  'Castelo Mendo': 'CastelosSECXIII/casteloMendo.html',
#  'Castelo Novo': 'CastelosSECXII/casteloNovo.html',
#  'Castelo Rodrigo': 'CastelosSECXII/casteloRodrigo.html',
#  'Castro Marim': 'Castelos(pre)SECXII/castroMarim.html',
#  'Castro Laboreiro': 'Castelos(pre)SECXII/castroLaboreiro.html',
#  'Celorico da Beira': 'CastelosSECXII/celoricoBeira.html',
#  'Ceras': 'Castelos(pre)SECXII/ceras.html',
#  'Chaves': 'Castelos(pre)SECXII/chaves.html',
#  'Coimbra': 'CastelosSECXII/coimbra.html',
#  'Cola': 'Castelos(pre)SECXII/cola.html',
#  'Covilhã': 'CastelosSECXII/covilha.html',
#  'Estremoz': 'CastelosSECXII/estremoz.html',
#  'Évora': 'Castelos(pos)SECXIII/evora.html',
#  'Évora Monte': 'CastelosSECXII/evoraMonte.html',
#  'Faria': 'Castelos(pre)SECXII/faria.html',
#  'Faro': 'Castelos(pre)SECXII/faro.html',
#  'Ferreira de Aves': 'CastelosSECXII/ferreiraAves.html',
#  'Folgosinho': 'Castelos(pre)SECXII/folgosinho.html',
#  'Freixo de Espada à Cinta': 'CastelosSECXII/freixoEspada.html',
#  'Gaia': 'Castelos(pre)SECXII/gaia.html',
#  'Germanelo': 'CastelosSECXII/germanelo.html',
#  'Giraldo': 'Castelos(pre)SECXII/giraldo.html',
#  'Gouveia': 'Castelos(pre)SECXII/gouveia.html',
#  'Guarda': 'CastelosSECXII/guarda.html',
#  'Guimarães': 'Castelos(pre)SECXII/guimaraes.html',
#  'Idanha-a-Nova': 'CastelosSECXII/idanhaNova.html',
#  'Idanha-a-Velha': 'CastelosSECXII/idanhaVelha.html',
#  'Lagos': 'Castelos(pre)SECXII/lagos.html',
#  'Lamego': 'Castelos(pre)SECXII/lamego.html',
#  'Lanhoso': 'Castelos(pre)SECXII/lanhoso.html',
#  'Leiria': 'CastelosSECXII/leiria.html',
#  'Lindoso': 'CastelosSECXIII/lindoso.html',
#  'Linhares da Beira': 'CastelosSECXII/linharesBeira.html',
#  'Longroiva': 'Castelos(pre)SECXII/longroiva.html',
#  'Loulé': 'Castelos(pre)SECXII/loule.html',
#  'Lourinhã': 'CastelosSECXII/lourinha.html',
#  'Lousã': 'Castelos(pre)SECXII/lousa.html',
#  'Marialva': 'CastelosSECXII/marialva.html',
#  'Mau Vizinho': 'Castelos(pre)SECXII/mauVizinho.html',
#  'Mau Vizinho(Évora)': 'Castelos(pre)SECXII/mauVizinhoEvora.html',
#  'Melgaço': 'CastelosSECXII/melgaco.html',
#  'Mértola': 'Castelos(pre)SECXII/mertola.html',
#  'Messejana': 'Castelos(pre)SECXII/messejana.html',
#  'Miranda do Douro': 'Castelos(pre)SECXII/mirandaDouro.html',
#  'Mogadouro': 'CastelosSECXII/mogadouro.html',
#  'Monforte': 'CastelosSECXII/monforte.html',
#  'Monforte (Fig.C.Rodrigo)': 'CastelosSECXII/monforteFigRodrigo.html',
#  'Monsanto': 'CastelosSECXII/monsanto.html',
#  'Monsaraz': 'CastelosSECXII/monsaraz.html',
#  'Montel': 'Castelos(pre)SECXII/montel.html',
#  'Montemor-o-Velho': 'Castelos(pre)SECXII/montemorVelho.html',
#  'Moreira de Rei': 'CastelosSECXII/moreiraRei.html',
#  'Neiva': 'Castelos(pre)SECXII/neiva.html',
#  'Numão': 'CastelosSECXII/numao.html',
#  'Óbidos': 'CastelosSECXII/obidos.html',
#  'Oleiros': 'Castelos(pre)SECXII/oleiros.html',
#  'Ourém': 'CastelosSECXII/ourem.html',
#  'Paderne': 'Castelos(pre)SECXII/paderne.html',
#  'Palmela': 'CastelosSECXII/palmela.html',
#  'Pena de Aguiar': 'Castelos(pre)SECXII/penaAguiar.html',
#  'Penacova': 'Castelos(pre)SECXII/penacova.html',
#  'Penamacor': 'CastelosSECXII/penamacor.html',
#  'Penas Róias': 'CastelosSECXII/penasRoias.html',
#  'Penedono': 'Castelos(pre)SECXII/penedono.html',
#  'Penela': 'CastelosSECXII/penela.html',
#  'Piconha': 'Castelos(pre)SECXII/piconha.html',
#  'Pinhel': 'CastelosSECXIII/pinhel.html',
#  'Pombal': 'CastelosSECXII/pombal.html',
#  'Portelo': 'Castelos(pre)SECXII/portelo.html',
#  'Porto de Mós': 'Castelos(pre)SECXII/portoMos.html',
#  'Proença-a-Velha': 'Castelos(pre)SECXII/proencaVelha.html',
#  'Rodão': 'CastelosSECXII/rodao.html',
#  'Relíquias': 'Castelos(pre)SECXII/reliquias.html',
#  'Romano da Lousa': 'Castelos(pre)SECXII/romanoLousa.html',
#  'Roqueiro de Coruto': 'Castelos(pre)SECXII/roqueiroCoruto.html',
#  'Sabugal': 'CastelosSECXII/sabugal.html',
#  'São Martinho de Mouros ': 'Castelos(pre)SECXII/martinhoMouros.html',
#  'São Jorge': 'Castelos(pre)SECXII/sJorge.html',
#  'Salir': 'Castelos(pre)SECXII/salir.html',
#  'Salvaterra do Extremo': 'CastelosSECXII/salvaterraExtremo.html',
#  'Santa Maria da Feira': 'Castelos(pre)SECXII/santaMaria.html',
#  'Santarém': 'Castelos(pre)SECXII/santarem.html',
#  'Santiago do Cacém': 'Castelos(pre)SECXII/santiagoCacem.html',
#  'Santo Estêvão': 'CastelosSECXII/santoEstevao.html',
#  'Seia': 'Castelos(pre)SECXII/seia.html',
#  'Sernancelhe': 'Castelos(pre)SECXII/sernancelhe.html',
#  'Sertã': 'CastelosSECXII/serta.html',
#  'Silves': 'Castelos(pre)SECXII/silves.html',
#  'Sines': 'Castelos(pos)SECXIII/sines.html',
#  'Sintra': 'Castelos(pre)SECXII/sintra.html',
#  'Soure': 'Castelos(pre)SECXII/soure.html',
#  'Sortelha': 'CastelosSECXIII/sortelha.html',
#  'Tarouca': 'Castelos(pre)SECXII/tarouca.html',
#  'Tavira': 'Castelos(pre)SECXII/tavira.html',
#  'Tomar': 'CastelosSECXII/tomar.html',
#  'Torres Novas': 'Castelos(pre)SECXII/torresNovas.html',
#  'Torres Vedras': 'Castelos(pre)SECXII/torresVedras.html',
#  'Trancoso': 'Castelos(pre)SECXII/trancoso.html',
#  'Veiros': 'CastelosSECXIII/veiros.html',
#  'Velho de Alcoutim': 'Castelos(pre)SECXII/velhoAlcoutim.html',
#  'Velho do Degebe': 'Castelos(pre)SECXII/velhoDegebe.html',
#  'Vermoim': 'Castelos(pre)SECXII/vermoim.html',
#  'Viana do Alentejo': 'Castelos(pos)SECXIII/vianaAlentejo.html',
#  'Vidigueira': 'CastelosSECXII/vidigueira.html',
#  'Vila Verde dos Francos': 'Castelos(pre)SECXII/verdeFrancos.html',
#  'Vila Viçosa': 'Castelos(pos)SECXIII/vilaVicosa.html',
#  'Vilar Maior': 'Castelos(pre)SECXII/vilarMaior.html',
#  'Vinhais': 'Castelos(pre)SECXII/vinhais.html',
#  'Viseu': 'Castelos(pre)SECXII/viseu.html'}

# %%
len(castles_html_dict)
# Out:
# 141

# %% [markdown]
# I retrieved the information for 141 Portuguese castles.

# %%
# This cell will make a request for each castle page and extract its information using BeautifulSoup
# and store it in the castles_dict dictionary

castles_dict = {}

for castle_name, castle_url in castles_html_dict.items():

    print('Parsing through ' + castle_name + ' castle...')

    # Make request
    response = requests.get(
      url='https://proxy.scrapeops.io/v1/',
      params={
          'api_key': API_KEY,
          'url': 'https://www.castelosdeportugal.pt/castelos/' + castle_url, 
      },
    )

    # Get soup

    castle_soup = BeautifulSoup(response.content, "html.parser")


    # Get smaller soups with the relevant information for each castle

    try:
        castle_soup = castle_soup.find_all('div', class_='table-responsive table-bordered')[0]
        castle_location = castle_soup.find_all('a')
        castle_info = castle_soup.find_all('td')
    except IndexError:
        castle_location = ['SEM INFO', 'SEM INFO']
        print('- No district information for ' + castle_name + ' castle!')
        print('- No council information for ' + castle_name + ' castle!')


    # Get the district and council where the castle is located

    try:
        castle_district = castle_location[0].string
    except IndexError:
        castle_district = 'SEM INFO'
        print('- No district information for ' + castle_name + ' castle!')

    try:    
        castle_council = castle_location[1].string   
    except IndexError:
        castle_council = 'SEM INFO'
        print('- No council information for ' + castle_name + ' castle!')


    # Get the century in which the castle was built

    try:
        castle_century = 0
    except NameError:
        pass

    for index, item in enumerate(castle_info):
        if 'Construção' in item.text:
            if castle_info[index+1].text != '( )':
                castle_century = castle_info[index+1].text
                castle_century = castle_century.replace('<td>', '').replace('</td>', '').replace('séc.', 'Século')
                print('- Found century/year info: ', castle_century)

    if castle_century == 0:
        castle_century = 'SEM INFO'
        print('- No century/year information for ' + castle_name + ' castle!')


    # Get the name of the king who had the castle built

    try:
        castle_king = 0
    except NameError:
        pass

    for index, item in enumerate(castle_info):
        if 'Reinado' in item.text:
            if castle_info[index+1].text != '( )':
                castle_king = castle_info[index+1].text
                castle_king = castle_king.replace('<td>', '').replace('</td>', '')
                print('- Found kingdom info: ', castle_king)

    if castle_king == 0:
        castle_king = 'SEM INFO'
        print('- No kingdom information for ' + castle_name + ' castle!')


    # Add information to castle dictionary

    castles_dict[castle_name] = {
        'district': castle_district,
        'council': castle_council,
        'century': castle_century,
        'king': castle_king,
        'coordinates': 'SEM COORDENADAS'   # Left this key-value pair as a placeholder for later
    }


    # Keeping ScrapeOps and castelosdeportugal.pt happy

    print('')
    wait_time = random.randrange(50, 100, 10)
    time.sleep(wait_time)
# Out:
# Parsing through Abrantes castle...
# - Found century/year info:  Século XII
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Aguiar Sousa castle...
# - No century/year information for Aguiar Sousa castle!
# - No kingdom information for Aguiar Sousa castle!
#
# Parsing through Alcácer do Sal castle...
# - Found century/year info:  Século XII
# - No kingdom information for Alcácer do Sal castle!
#
# Parsing through Alcanede castle...
# - No century/year information for Alcanede castle!
# - No kingdom information for Alcanede castle!
#
# Parsing through Alcobaça castle...
# - Found century/year info:  (c.650)
# - No kingdom information for Alcobaça castle!
#
# Parsing through Alcantarilha castle...
# - Found century/year info:  Séc. XII
# - No kingdom information for Alcantarilha castle!
#
# Parsing through Alfaiates castle...
# - Found century/year info:  (Século XII)?
# - No kingdom information for Alfaiates castle!
#
# Parsing through Alfeizerão castle...
# - Found century/year info:  c. 1147
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Aljezur castle...
# - Found century/year info:  Século X
# - No kingdom information for Aljezur castle!
#
# Parsing through Aljustrel castle...
# - Found century/year info:  Sec XII
# - No kingdom information for Aljustrel castle!
#
# Parsing through Alenquer castle...
# - Found century/year info:  1148
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Almada castle...
# - Found century/year info:  1170
# - Found kingdom info:  Afonso I de Portugal
#
# Parsing through Almourol castle...
# - Found century/year info:  1171
# - No kingdom information for Almourol castle!
#
# Parsing through Alter do Chão castle...
# - Found century/year info:  1357
# - Found kingdom info:  D. Pedro I
#
# Parsing through Alva castle...
# - No century/year information for Alva castle!
# - No kingdom information for Alva castle!
#
# Parsing through Alvito castle...
# - Found century/year info:  1494
# - No kingdom information for Alvito castle!
#
# Parsing through Alvor castle...
# - No century/year information for Alvor castle!
# - No kingdom information for Alvor castle!
#
# Parsing through Amieira castle...
# - Found century/year info:  1350
# - Found kingdom info:  D. Afonso IV
#
# Parsing through Alpalhão castle...
# - Found century/year info:  (séc XII)?
# - No kingdom information for Alpalhão castle!
#
# Parsing through Arraiolos castle...
# - Found century/year info:  1306
# - Found kingdom info:  D. Dinis I
#
# Parsing through Ansiães castle...
# - No century/year information for Ansiães castle!
# - No kingdom information for Ansiães castle!
#
# Parsing through Atouguia da Baleia castle...
# - No century/year information for Atouguia da Baleia castle!
# - No kingdom information for Atouguia da Baleia castle!
#
# Parsing through Avô castle...
# - Found century/year info:  Século XII
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Barcelos castle...
# - No century/year information for Barcelos castle!
# - No kingdom information for Barcelos castle!
#
# Parsing through Braga castle...
# - No century/year information for Braga castle!
# - Found kingdom info:  D. Dinis
#
# Parsing through Bragança castle...
# - Found century/year info:  Século XIII
# - Found kingdom info:  Fernão Mendes ou D. Sancho I
#
# Parsing through Cabeço de Vide castle...
# - Found century/year info:  (Séc. XII)?
# - No kingdom information for Cabeço de Vide castle!
#
# Parsing through Cacela castle...
# - No century/year information for Cacela castle!
# - No kingdom information for Cacela castle!
#
# Parsing through Caminha castle...
# - No century/year information for Caminha castle!
# - No kingdom information for Caminha castle!
#
# Parsing through Carrapatoso castle...
# - No century/year information for Carrapatoso castle!
# - No kingdom information for Carrapatoso castle!
#
# Parsing through Castelo Bom castle...
# - Found century/year info:  1297
# - Found kingdom info:  D. Dinis
#
# Parsing through Castelo Melhor castle...
# - No century/year information for Castelo Melhor castle!
# - No kingdom information for Castelo Melhor castle!
#
# Parsing through Castelo Mendo castle...
# - Found century/year info:  1297
# - Found kingdom info:  D. Dinis
#
# Parsing through Castelo Novo castle...
# - No century/year information for Castelo Novo castle!
# - No kingdom information for Castelo Novo castle!
#
# Parsing through Castelo Rodrigo castle...
# - Found century/year info:  (Século XII)?
# - No kingdom information for Castelo Rodrigo castle!
#
# Parsing through Castro Marim castle...
# - No century/year information for Castro Marim castle!
# - No kingdom information for Castro Marim castle!
#
# Parsing through Castro Laboreiro castle...
# - No century/year information for Castro Laboreiro castle!
# - No kingdom information for Castro Laboreiro castle!
#
# Parsing through Celorico da Beira castle...
# - Found century/year info:  Séc. XII
# - Found kingdom info:  Afonso I de Portugal
#
# Parsing through Ceras castle...
# - No century/year information for Ceras castle!
# - No kingdom information for Ceras castle!
#
# Parsing through Chaves castle...
# - Found century/year info:  Século IX
# - Found kingdom info:  Afonso III das Astúrias
#
# Parsing through Coimbra castle...
# - No council information for Coimbra castle!
# - Found century/year info:  (Século XII)?
# - No kingdom information for Coimbra castle!
#
# Parsing through Cola castle...
# - Found century/year info:  Idade do Bronze
# - No kingdom information for Cola castle!
#
# Parsing through Covilhã castle...
# - Found century/year info:  (1188)?
# - Found kingdom info:  D. Sancho I de Portugal
#
# Parsing through Estremoz castle...
# - Found century/year info:  (Século XII)?
# - No kingdom information for Estremoz castle!
#
# Parsing through Évora castle...
# - No council information for Évora castle!
# - No century/year information for Évora castle!
# - Found kingdom info:  D. Afonso IV
#
# Parsing through Évora Monte castle...
# - Found century/year info:  (1160)?
# - Found kingdom info:  Afonso I de Portugal
#
# Parsing through Faria castle...
# - No century/year information for Faria castle!
# - No kingdom information for Faria castle!
#
# Parsing through Faro castle...
# - No century/year information for Faro castle!
# - No kingdom information for Faro castle!
#
# Parsing through Ferreira de Aves castle...
# - Found century/year info:  (Séc XII)?
# - No kingdom information for Ferreira de Aves castle!
#
# Parsing through Folgosinho castle...
# - No century/year information for Folgosinho castle!
# - No kingdom information for Folgosinho castle!
#
# Parsing through Freixo de Espada à Cinta castle...
# - Found century/year info:  (Séc. XII)?
# - No kingdom information for Freixo de Espada à Cinta castle!
#
# Parsing through Gaia castle...
# - No century/year information for Gaia castle!
# - No kingdom information for Gaia castle!
#
# Parsing through Germanelo castle...
# - Found century/year info:  1142
# - Found kingdom info:  Afonso I
#
# Parsing through Giraldo castle...
# - No century/year information for Giraldo castle!
# - No kingdom information for Giraldo castle!
#
# Parsing through Gouveia castle...
# - No century/year information for Gouveia castle!
# - No kingdom information for Gouveia castle!
#
# Parsing through Guarda castle...
# - No council information for Guarda castle!
# - Found century/year info:  Século XII
# - Found kingdom info:  D. Sancho I
#
# Parsing through Guimarães castle...
# - Found century/year info:  (ant. a 958)
# - No kingdom information for Guimarães castle!
#
# Parsing through Idanha-a-Nova castle...
# - Found century/year info:  (séc XII)?
# - No kingdom information for Idanha-a-Nova castle!
#
# Parsing through Idanha-a-Velha castle...
# - Found century/year info:  (séc XII)?
# - No kingdom information for Idanha-a-Velha castle!
#
# Parsing through Lagos castle...
# - No century/year information for Lagos castle!
# - No kingdom information for Lagos castle!
#
# Parsing through Lamego castle...
# - No century/year information for Lamego castle!
# - No kingdom information for Lamego castle!
#
# Parsing through Lanhoso castle...
# - No century/year information for Lanhoso castle!
# - No kingdom information for Lanhoso castle!
#
# Parsing through Leiria castle...
# - No council information for Leiria castle!
# - Found century/year info:  Século XII
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Lindoso castle...
# - No century/year information for Lindoso castle!
# - Found kingdom info:  D. Afonso III
#
# Parsing through Linhares da Beira castle...
# - Found century/year info:  (Século XII)?
# - No kingdom information for Linhares da Beira castle!
#
# Parsing through Longroiva castle...
# - No century/year information for Longroiva castle!
# - No kingdom information for Longroiva castle!
#
# Parsing through Loulé castle...
# - No century/year information for Loulé castle!
# - No kingdom information for Loulé castle!
#
# Parsing through Lourinhã castle...
# - Found century/year info:  Séc. XII
# - No kingdom information for Lourinhã castle!
#
# Parsing through Lousã castle...
# - No century/year information for Lousã castle!
# - No kingdom information for Lousã castle!
#
# Parsing through Marialva castle...
# - Found century/year info:  c. 1179
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Mau Vizinho castle...
# - No century/year information for Mau Vizinho castle!
# - No kingdom information for Mau Vizinho castle!
#
# Parsing through Mau Vizinho(Évora) castle...
# - No century/year information for Mau Vizinho(Évora) castle!
# - No kingdom information for Mau Vizinho(Évora) castle!
#
# Parsing through Melgaço castle...
# - Found century/year info:  c. 1170
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Mértola castle...
# - Found century/year info:  (930 - 1031)
# - No kingdom information for Mértola castle!
#
# Parsing through Messejana castle...
# - No century/year information for Messejana castle!
# - No kingdom information for Messejana castle!
#
# Parsing through Miranda do Douro castle...
# - No century/year information for Miranda do Douro castle!
# - No kingdom information for Miranda do Douro castle!
#
# Parsing through Mogadouro castle...
# - Found century/year info:  1160
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Monforte castle...
# - Found century/year info:  (Século XII)?
# - No kingdom information for Monforte castle!
#
# Parsing through Monforte (Fig.C.Rodrigo) castle...
# - Found century/year info:  (1188)?
# - No kingdom information for Monforte (Fig.C.Rodrigo) castle!
#
# Parsing through Monsanto castle...
# - Found century/year info:  Séc. XII
# - Found kingdom info:  Templários
#
# Parsing through Monsaraz castle...
# - No century/year information for Monsaraz castle!
# - No kingdom information for Monsaraz castle!
#
# Parsing through Montel castle...
# - No century/year information for Montel castle!
# - No kingdom information for Montel castle!
#
# Parsing through Montemor-o-Velho castle...
# - Found century/year info:  (1088)
# - Found kingdom info:  Afonso VI de Leão e Castela
#
# Parsing through Moreira de Rei castle...
# - Found century/year info:  Século XII
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Neiva castle...
# - No century/year information for Neiva castle!
# - No kingdom information for Neiva castle!
#
# Parsing through Numão castle...
# - Found century/year info:  1130
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Óbidos castle...
# - Found century/year info:  Século XII-Século XIII
# - No kingdom information for Óbidos castle!
#
# Parsing through Oleiros castle...
# - No century/year information for Oleiros castle!
# - No kingdom information for Oleiros castle!
#
# Parsing through Ourém castle...
# - Found century/year info:  Século XII
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Paderne castle...
# - Found century/year info:  Séculos XI ou XII
# - Found kingdom info:  Califado Almóada
#
# Parsing through Palmela castle...
# - Found century/year info:  (Séc. XII)?
# - No kingdom information for Palmela castle!
#
# Parsing through Pena de Aguiar castle...
# - No century/year information for Pena de Aguiar castle!
# - No kingdom information for Pena de Aguiar castle!
#
# Parsing through Penacova castle...
# - Found century/year info:  Século X
# - No kingdom information for Penacova castle!
#
# Parsing through Penamacor castle...
# - Found century/year info:  1199
# - Found kingdom info:  D. Sancho I
#
# Parsing through Penas Róias castle...
# - Found century/year info:  1166
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Penedono castle...
# - Found century/year info:  c. 900
# - No kingdom information for Penedono castle!
#
# Parsing through Penela castle...
# - Found century/year info:  c. 1140
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Piconha castle...
# - No century/year information for Piconha castle!
# - No kingdom information for Piconha castle!
#
# Parsing through Pinhel castle...
# - Found century/year info:  1209
# - Found kingdom info:  D. Sancho I
#
# Parsing through Pombal castle...
# - Found century/year info:  1161
# - Found kingdom info:  Gualdim Pais
#
# Parsing through Portelo castle...
# - No century/year information for Portelo castle!
# - No kingdom information for Portelo castle!
#
# Parsing through Porto de Mós castle...
# - No century/year information for Porto de Mós castle!
# - No kingdom information for Porto de Mós castle!
#
# Parsing through Proença-a-Velha castle...
# - No century/year information for Proença-a-Velha castle!
# - No kingdom information for Proença-a-Velha castle!
#
# Parsing through Rodão castle...
# - Found century/year info:  (séc XII)?
# - No kingdom information for Rodão castle!
#
# Parsing through Relíquias castle...
# - No century/year information for Relíquias castle!
# - No kingdom information for Relíquias castle!
#
# Parsing through Romano da Lousa castle...
# - Found century/year info:  Séculos II e I a.C.
# - No kingdom information for Romano da Lousa castle!
#
# Parsing through Roqueiro de Coruto castle...
# - No century/year information for Roqueiro de Coruto castle!
# - No kingdom information for Roqueiro de Coruto castle!
#
# Parsing through Sabugal castle...
# - Found century/year info:  ? Século XII
# - No kingdom information for Sabugal castle!
#
# Parsing through São Martinho de Mouros  castle...
# - No century/year information for São Martinho de Mouros  castle!
# - No kingdom information for São Martinho de Mouros  castle!
#
# Parsing through São Jorge castle...
# - No century/year information for São Jorge castle!
# - No kingdom information for São Jorge castle!
#
# Parsing through Salir castle...
# - No century/year information for Salir castle!
# - No kingdom information for Salir castle!
#
# Parsing through Salvaterra do Extremo castle...
# - Found century/year info:  (séc XII)?
# - No kingdom information for Salvaterra do Extremo castle!
#
# Parsing through Santa Maria da Feira castle...
# - Found century/year info:  Anterior ao século XI
# - No kingdom information for Santa Maria da Feira castle!
#
# Parsing through Santarém castle...
# - No century/year information for Santarém castle!
# - No kingdom information for Santarém castle!
#
# Parsing through Santiago do Cacém castle...
# - No century/year information for Santiago do Cacém castle!
# - No kingdom information for Santiago do Cacém castle!
#
# Parsing through Santo Estêvão castle...
# - Found century/year info:  1160
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Seia castle...
# - No century/year information for Seia castle!
# - No kingdom information for Seia castle!
#
# Parsing through Sernancelhe castle...
# - No century/year information for Sernancelhe castle!
# - No kingdom information for Sernancelhe castle!
#
# Parsing through Sertã castle...
# - Found century/year info:  Século XI ou XII
# - Found kingdom info:  Henrique de Borgonha
#
# Parsing through Silves castle...
# - Found century/year info:  (716)
# - No kingdom information for Silves castle!
#
# Parsing through Sines castle...
# - Found century/year info:  1424
# - Found kingdom info:  D. João I
#
# Parsing through Sintra castle...
# - Found century/year info:  Século VIII e Século IX
# - No kingdom information for Sintra castle!
#
# Parsing through Soure castle...
# - No century/year information for Soure castle!
# - No kingdom information for Soure castle!
#
# Parsing through Sortelha castle...
# - Found century/year info:  1228
# - Found kingdom info:  D. Sancho II
#
# Parsing through Tarouca castle...
# - No council information for Tarouca castle!
# - Found century/year info:  Século XI
# - No kingdom information for Tarouca castle!
#
# Parsing through Tavira castle...
# - No century/year information for Tavira castle!
# - No kingdom information for Tavira castle!
#
# Parsing through Tomar castle...
# - Found century/year info:  1160
# - Found kingdom info:  D. Afonso Henriques
#
# Parsing through Torres Novas castle...
# - No century/year information for Torres Novas castle!
# - No kingdom information for Torres Novas castle!
# Parsing through Torres Vedras castle...
# - No century/year information for Torres Vedras castle!
# - No kingdom information for Torres Vedras castle!
#
# Parsing through Trancoso castle...
# - No century/year information for Trancoso castle!
# - No kingdom information for Trancoso castle!
#
# Parsing through Veiros castle...
# - No century/year information for Veiros castle!
# - No kingdom information for Veiros castle!
#
# Parsing through Velho de Alcoutim castle...
# - Found century/year info:  Século VIII
# - Found kingdom info:  Califado Omíada
#
# Parsing through Velho do Degebe castle...
# - Found century/year info:  Idade do Ferro
# - No kingdom information for Velho do Degebe castle!
#
# Parsing through Vermoim castle...
# - Found century/year info:  (ant. a 977)
# - No kingdom information for Vermoim castle!
#
# Parsing through Viana do Alentejo castle...
# - Found century/year info:  1313
# - Found kingdom info:  D. Dinis I
#
# Parsing through Vidigueira castle...
# - Found century/year info:  (Séc. XII)?
# - No kingdom information for Vidigueira castle!
#
# Parsing through Vila Verde dos Francos castle...
# - No century/year information for Vila Verde dos Francos castle!
# - No kingdom information for Vila Verde dos Francos castle!
#
# Parsing through Vila Viçosa castle...
# - Found century/year info:  Século XIV
# - Found kingdom info:  D. Dinis I
#
# Parsing through Vilar Maior castle...
# - No century/year information for Vilar Maior castle!
# - No kingdom information for Vilar Maior castle!
#
# Parsing through Vinhais castle...
# - No century/year information for Vinhais castle!
# - No kingdom information for Vinhais castle!
#
# Parsing through Viseu castle...
# - No century/year information for Viseu castle!
# - No kingdom information for Viseu castle!

# %%
castles_dict
# Out:
# {'Abrantes': {'district': 'Santarém',
#   'council': 'Abrantes',
#   'century': 'Século XII',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Aguiar Sousa': {'district': 'Porto',
#   'council': 'Paredes',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alcácer do Sal': {'district': 'Setúbal',
#   'council': 'Alcácer do Sal',
#   'century': 'Século XII',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alcanede': {'district': 'Santarém',
#   'council': 'Alcanede',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alcobaça': {'district': 'Leiria',
#   'council': 'Alcobaça',
#   'century': '(c.650)',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alcantarilha': {'district': 'Faro',
#   'council': 'Silves',
#   'century': 'Séc. XII',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alfaiates': {'district': 'Guarda',
#   'council': 'Sabugal',
#   'century': '(Século XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alfeizerão': {'district': 'Leiria',
#   'council': 'Alcobaça',
#   'century': 'c. 1147',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Aljezur': {'district': 'Faro',
#   'council': 'Aljezur',
#   'century': 'Século X',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Aljustrel': {'district': 'Beja',
#   'council': 'Aljustrel',
#   'century': 'Sec XII',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alenquer': {'district': 'Lisboa',
#   'council': 'Alenquer',
#   'century': '1148',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Almada': {'district': 'Setúbal',
#   'council': 'Almada',
#   'century': '1170',
#   'king': 'Afonso I de Portugal',
#   'coordinates': 'SEM COORDENADAS'},
#  'Almourol': {'district': 'Santarém',
#   'council': 'Vila Nova da Barquinha',
#   'century': '1171',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alter do Chão': {'district': 'Portalegre',
#   'council': 'Alter do Chão',
#   'century': '1357',
#   'king': 'D. Pedro I',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alva': {'district': 'Bragança',
#   'council': 'Freixo de Espada à Cinta',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alvito': {'district': 'Beja',
#   'council': 'Alvito',
#   'century': '1494',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alvor': {'district': 'Faro',
#   'council': 'Portimão',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Amieira': {'district': 'Portalegre',
#   'council': 'Amieira',
#   'century': '1350',
#   'king': 'D. Afonso IV',
#   'coordinates': 'SEM COORDENADAS'},
#  'Alpalhão': {'district': 'Portalegre',
#   'council': 'Nisa',
#   'century': '(séc XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Arraiolos': {'district': 'Évora',
#   'council': 'Arraiolos',
#   'century': '1306',
#   'king': 'D. Dinis I',
#   'coordinates': 'SEM COORDENADAS'},
#  'Ansiães': {'district': 'Bragança',
#   'council': 'Carrazeda de Ansiães',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Atouguia da Baleia': {'district': 'Leiria',
#   'council': 'Peniche',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Avô': {'district': 'Coimbra',
#   'council': 'Oliveira do Hospital',
#   'century': 'Século XII',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Barcelos': {'district': 'Braga',
#   'council': 'Barcelos',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Braga': {'district': 'Braga',
#   'council': 'São João do Souto',
#   'century': 'SEM INFO',
#   'king': 'D. Dinis',
#   'coordinates': 'SEM COORDENADAS'},
#  'Bragança': {'district': 'Bragança',
#   'council': 'Santa Maria',
#   'century': 'Século XIII',
#   'king': 'Fernão Mendes ou D. Sancho I ',
#   'coordinates': 'SEM COORDENADAS'},
#  'Cabeço de Vide': {'district': 'Portalegre',
#   'council': 'Fronteira',
#   'century': '(Séc. XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Cacela': {'district': 'Faro',
#   'council': 'Vila Real de Santo António',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Caminha': {'district': 'Viana do Castelo',
#   'council': 'Caminha',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Carrapatoso': {'district': 'Leiria',
#   'council': 'Torres Novas',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Castelo Bom': {'district': 'Guarda',
#   'council': 'Almeida',
#   'century': '1297',
#   'king': 'D. Dinis',
#   'coordinates': 'SEM COORDENADAS'},
#  'Castelo Melhor': {'district': 'Guarda',
#   'council': 'Vila Nova de Foz Côa',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Castelo Mendo': {'district': 'Guarda',
#   'council': 'Almeida',
#   'century': '1297',
#   'king': 'D. Dinis',
#   'coordinates': 'SEM COORDENADAS'},
#  'Castelo Novo': {'district': 'Castelo Branco',
#   'council': 'Fundão',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Castelo Rodrigo': {'district': 'Guarda',
#   'council': 'Figueira de Castelo Rodrigo',
#   'century': '(Século XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Castro Marim': {'district': 'Faro',
#   'council': 'Castro Marim',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Castro Laboreiro': {'district': 'Viana do Castelo',
#   'council': 'Melgaço',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Celorico da Beira': {'district': 'Guarda',
#   'council': 'Celorico da Beira',
#   'century': 'Séc. XII',
#   'king': 'Afonso I de Portugal',
#   'coordinates': 'SEM COORDENADAS'},
#  'Ceras': {'district': 'Santarém',
#   'council': 'Tomar',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Chaves': {'district': 'Vila Real',
#   'council': 'Chaves',
#   'century': 'Século IX',
#   'king': 'Afonso III das Astúrias',
#   'coordinates': 'SEM COORDENADAS'},
#  'Coimbra': {'district': 'Coimbra',
#   'council': 'SEM INFO',
#   'century': '(Século XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Cola': {'district': 'Beja',
#   'council': 'Ourique',
#   'century': 'Idade do Bronze',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Covilhã': {'district': 'Castelo Branco',
#   'council': 'Covilhã',
#   'century': '(1188)?',
#   'king': 'D. Sancho I de Portugal',
#   'coordinates': 'SEM COORDENADAS'},
#  'Estremoz': {'district': 'Évora',
#   'council': 'Estremoz',
#   'century': '(Século XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Évora': {'district': 'Évora',
#   'council': 'SEM INFO',
#   'century': 'SEM INFO',
#   'king': 'D. Afonso IV',
#   'coordinates': 'SEM COORDENADAS'},
#  'Évora Monte': {'district': 'Évora',
#   'council': 'Estremoz',
#   'century': '(1160)?',
#   'king': 'Afonso I de Portugal',
#   'coordinates': 'SEM COORDENADAS'},
#  'Faria': {'district': 'Braga',
#   'council': 'Barcelos',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Faro': {'district': 'Faro',
#   'council': 'Faro (Sé e São Pedro)',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Ferreira de Aves': {'district': 'Viseu',
#   'council': 'Sátão',
#   'century': '(Séc XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Folgosinho': {'district': 'Guarda',
#   'council': 'Gouveia',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Freixo de Espada à Cinta': {'district': 'Bragança',
#   'council': 'Freixo de Espada à Cinta',
#   'century': '(Séc. XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Gaia': {'district': 'Porto',
#   'council': 'Vila Nova de Gaia',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Germanelo': {'district': 'Coimbra',
#   'council': 'Penela',
#   'century': '1142',
#   'king': 'Afonso I',
#   'coordinates': 'SEM COORDENADAS'},
#  'Giraldo': {'district': 'Évora',
#   'council': 'Nossa Senhora de Guadalupe',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Gouveia': {'district': 'Guarda',
#   'council': 'Gouveia',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Guarda': {'district': 'Guarda',
#   'council': 'SEM INFO',
#   'century': 'Século XII',
#   'king': 'D. Sancho I',
#   'coordinates': 'SEM COORDENADAS'},
#  'Guimarães': {'district': 'Guimarães',
#   'council': 'Oliveira do Castelo',
#   'century': '(ant. a 958)',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Idanha-a-Nova': {'district': 'Castelo Branco',
#   'council': 'Idanha-a-Nova',
#   'century': '(séc XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Idanha-a-Velha': {'district': 'Castelo Branco',
#   'council': 'Idanha-a-Nova',
#   'century': '(séc XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Lagos': {'district': 'Faro',
#   'council': 'Lagos',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Lamego': {'district': 'Viseu',
#   'council': 'Lamego',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Lanhoso': {'district': 'Braga',
#   'council': 'Póvoa de Lanhoso',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Leiria': {'district': 'Leiria',
#   'council': 'SEM INFO',
#   'century': 'Século XII',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Lindoso': {'district': 'Viana do Castelo',
#   'council': 'Ponte da Barca',
#   'century': 'SEM INFO',
#   'king': 'D. Afonso III',
#   'coordinates': 'SEM COORDENADAS'},
#  'Linhares da Beira': {'district': 'Guarda',
#   'council': 'Celorico da Beira',
#   'century': '(Século XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Longroiva': {'district': 'Guarda',
#   'council': 'Mêda',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Loulé': {'district': 'Faro',
#   'council': 'Loulé',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Lourinhã': {'district': 'Lisboa',
#   'council': 'Lourinhã',
#   'century': 'Séc. XII',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Lousã': {'district': 'Coimbra',
#   'council': 'Lousã',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Marialva': {'district': 'Guarda',
#   'council': 'Mêda',
#   'century': 'c. 1179',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Mau Vizinho': {'district': 'Vila Real',
#   'council': 'Chaves',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Mau Vizinho(Évora)': {'district': 'Évora',
#   'council': 'Arraiolos',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Melgaço': {'district': 'Viana do Castelo',
#   'council': 'Melgaço',
#   'century': 'c. 1170',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Mértola': {'district': 'Beja',
#   'council': 'Mértola',
#   'century': '(930 - 1031)',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Messejana': {'district': 'Beja',
#   'council': 'Aljustrel',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Miranda do Douro': {'district': 'Bragança',
#   'council': 'Miranda do Douro',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Mogadouro': {'district': 'Bragança',
#   'council': 'Mogadouro',
#   'century': '1160',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Monforte': {'district': 'Vila Real',
#   'council': 'Chaves',
#   'century': '(Século XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Monforte (Fig.C.Rodrigo)': {'district': 'Guarda',
#   'council': 'Figueira de Castelo Rodrigo',
#   'century': '(1188)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Monsanto': {'district': 'Castelo Branco',
#   'council': 'Idanha-a-Nova',
#   'century': 'Séc. XII',
#   'king': 'Templários',
#   'coordinates': 'SEM COORDENADAS'},
#  'Monsaraz': {'district': 'Évora',
#   'council': 'Reguengos de Monsaraz',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Montel': {'district': 'Beja',
#   'council': 'Castro Verde',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Montemor-o-Velho': {'district': 'Coimbra',
#   'council': 'Montemor-o-Velho',
#   'century': '(1088)',
#   'king': 'Afonso VI de Leão e Castela',
#   'coordinates': 'SEM COORDENADAS'},
#  'Moreira de Rei': {'district': 'Guarda',
#   'council': 'Trancoso',
#   'century': 'Século XII',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Neiva': {'district': 'Viana do Castelo',
#   'council': 'Castelo do Neiva',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Numão': {'district': 'Guarda',
#   'council': None,
#   'century': '1130',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Óbidos': {'district': 'Leiria',
#   'council': 'Óbidos',
#   'century': 'Século XII-Século XIII',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Oleiros': {'district': 'Bragança',
#   'council': 'Mogadouro',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Ourém': {'district': 'Santarém',
#   'council': 'Ourém',
#   'century': 'Século XII',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Paderne': {'district': 'Faro',
#   'council': 'Albufeira',
#   'century': 'Séculos XI ou XII ',
#   'king': 'Califado Almóada',
#   'coordinates': 'SEM COORDENADAS'},
#  'Palmela': {'district': 'Setúbal',
#   'council': 'Palmela',
#   'century': '(Séc. XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Pena de Aguiar': {'district': 'Vila Real',
#   'council': 'Vila Pouca de Aguiar',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Penacova': {'district': 'Coimbra',
#   'council': 'Penacova',
#   'century': 'Século X',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Penamacor': {'district': 'Castelo Branco',
#   'council': 'Penamacor',
#   'century': '1199',
#   'king': 'D. Sancho I',
#   'coordinates': 'SEM COORDENADAS'},
#  'Penas Róias': {'district': 'Bragança',
#   'council': 'Mogadouro',
#   'century': '1166',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Penedono': {'district': 'Viseu',
#   'council': 'Penedono',
#   'century': 'c. 900',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Penela': {'district': 'Coimbra',
#   'council': 'Penela',
#   'century': 'c. 1140',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Piconha': {'district': 'Vila Real',
#   'council': 'Montalegre',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Pinhel': {'district': 'Guarda',
#   'council': 'Pinhel',
#   'century': '1209',
#   'king': 'D. Sancho I',
#   'coordinates': 'SEM COORDENADAS'},
#  'Pombal': {'district': 'Leiria',
#   'council': 'Pombal',
#   'century': '1161',
#   'king': 'Gualdim Pais',
#   'coordinates': 'SEM COORDENADAS'},
#  'Portelo': {'district': 'Vila Real',
#   'council': 'Montalegre',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Porto de Mós': {'district': 'Leiria',
#   'council': 'Porto de Mós',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Proença-a-Velha': {'district': 'Castelo Branco',
#   'council': 'Idanha-a-Nova',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Rodão': {'district': 'Castelo Branco',
#   'council': 'Vila Velha de Ródão',
#   'century': '(séc XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Relíquias': {'district': 'Faro',
#   'council': 'Alcoutim',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Romano da Lousa': {'district': 'Évora',
#   'council': 'Mourão',
#   'century': 'Séculos II e I a.C.',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Roqueiro de Coruto': {'district': 'Aveiro',
#   'council': 'Arouca',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Sabugal': {'district': 'Guarda',
#   'council': 'Sabugal',
#   'century': '? Século XII',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'São Martinho de Mouros ': {'district': 'Viseu',
#   'council': 'Resende',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'São Jorge': {'district': 'Lisboa',
#   'council': 'Santa Maria Maior',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Salir': {'district': 'Faro',
#   'council': 'Loulé',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Salvaterra do Extremo': {'district': 'Castelo Branco',
#   'council': 'Idanha-a-Nova',
#   'century': '(séc XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Santa Maria da Feira': {'district': 'Aveiro',
#   'council': 'Santa Maria da Feira',
#   'century': 'Anterior ao século XI',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Santarém': {'district': 'Santarém',
#   'council': 'Marvila (ext.)',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Santiago do Cacém': {'district': 'Setúbal',
#   'council': 'Santiago do Cacém',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Santo Estêvão': {'district': 'Vila Real',
#   'council': 'Chaves',
#   'century': '1160',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Seia': {'district': 'Guarda',
#   'council': 'Seia',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Sernancelhe': {'district': 'Viseu',
#   'council': 'Sernancelhe',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Sertã': {'district': 'Castelo Branco',
#   'council': 'Sertã',
#   'century': 'Século XI ou XII',
#   'king': 'Henrique de Borgonha',
#   'coordinates': 'SEM COORDENADAS'},
#  'Silves': {'district': 'Faro',
#   'council': 'Silves',
#   'century': '(716)',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Sines': {'district': 'Setúbal',
#   'council': 'Sines',
#   'century': '1424',
#   'king': 'D. João I',
#   'coordinates': 'SEM COORDENADAS'},
#  'Sintra': {'district': 'Lisboa',
#   'council': 'Sintra',
#   'century': 'Século VIII e Século IX',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Soure': {'district': 'Coimbra',
#   'council': 'soure',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Sortelha': {'district': 'Guarda',
#   'council': 'Sabugal',
#   'century': '1228',
#   'king': 'D. Sancho II',
#   'coordinates': 'SEM COORDENADAS'},
#  'Tarouca': {'district': 'Tarouca',
#   'council': 'SEM INFO',
#   'century': 'Século XI',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Tavira': {'district': 'Faro',
#   'council': 'Tavira',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Tomar': {'district': 'Santarém',
#   'council': 'Tomar',
#   'century': '1160',
#   'king': 'D. Afonso Henriques',
#   'coordinates': 'SEM COORDENADAS'},
#  'Torres Novas': {'district': 'Santarém',
#   'council': 'Torres Novas',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Torres Vedras': {'district': 'Lisboa',
#   'council': 'Torres Vedras',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Trancoso': {'district': 'Guarda',
#   'council': 'Trancoso',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Veiros': {'district': 'Évora',
#   'council': 'Estremoz',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Velho de Alcoutim': {'district': 'Faro',
#   'council': 'Alcoutim',
#   'century': 'Século VIII',
#   'king': 'Califado Omíada',
#   'coordinates': 'SEM COORDENADAS'},
#  'Velho do Degebe': {'district': 'Évora',
#   'council': 'Reguengos de Monsaraz',
#   'century': 'Idade do Ferro',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Vermoim': {'district': 'Vila Nova de Famalicão',
#   'council': 'Vermoim',
#   'century': '(ant. a 977)',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Viana do Alentejo': {'district': 'Évora',
#   'council': 'Viana do Alentejo',
#   'century': '1313',
#   'king': 'D. Dinis I',
#   'coordinates': 'SEM COORDENADAS'},
#  'Vidigueira': {'district': 'Beja',
#   'council': 'Vidigueira',
#   'century': '(Séc. XII)?',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Vila Verde dos Francos': {'district': 'Lisboa',
#   'council': 'Alenquer',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Vila Viçosa': {'district': 'Évora',
#   'council': 'Vila Viçosa',
#   'century': 'Século XIV',
#   'king': 'D. Dinis I',
#   'coordinates': 'SEM COORDENADAS'},
#  'Vilar Maior': {'district': 'Guarda',
#   'council': 'Sabugal',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Vinhais': {'district': 'Bragança',
#   'council': 'Vinhais',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'},
#  'Viseu': {'district': 'Viseu',
#   'council': 'Santa Maria de Viseu',
#   'century': 'SEM INFO',
#   'king': 'SEM INFO',
#   'coordinates': 'SEM COORDENADAS'}}
